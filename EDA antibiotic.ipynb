# %%
import sys
# !{sys.executable} -m pip install numpy 
# !{sys.executable} -m pip install pandas 
# !{sys.executable}-m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 20.0.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 20.0.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# /bin/bash: /usr/bin/python3-m: No such file or directory

# %%
import pandas as pd
import numpy as np

# %%
dataFrameMulti=pd.read_csv('multi.csv')

# %%
dataFramePheno=pd.read_csv('pheno.csv')

# %%
dataFrameMulti.head(5)
# Out:
#         prename  X393  X588  X747  X759  X774  X966  X1299  X1302  X1407  ...  \
# 0  H100_S2_L001     2     1     2     4     3     3      3      3      4  ...
# 1  H105_S3_L001     2     1     2     4     3     3      3      3      4  ...
# 2  H108_S5_L001     2     1     2     4     3     3      0      0      4  ...
# 3  H109_S2_L001     2     1     2     4     3     3      3      3      4  ...
# 4  H113_S6_L001     0     0     2     4     3     3      3      3      4  ...
#
#    X4639956.3  X4640785.3  X4640908.3  X4640924.3  X4641031.3  X4641131.3  \
# 0           3           4           4           2           1           3
# 1           3           4           4           2           1           3
# 2           3           4           4           2           1           3
# 3           3           4           4           2           1           3
# 4           3           4           0           0           2           3
#
#    X4641217.3  X4641296.3  X4641439.3  X4641440.3
# ...

# %%
dataFramePheno.head(5)
# Out:
#         prename  CIP  CTX  CTZ  GEN
# 0  H100_S2_L001    0    1    0    0
# 1  H105_S3_L001    1    1    0    0
# 2  H108_S5_L001    0    1    0    0
# 3  H109_S2_L001    0    1    0    0
# 4  H113_S6_L001    1    1    0    0

# %%
dataFrameMulti.shape
# Out:
# (809, 60937)

# %%
dataFramePheno.shape
# Out:
# (809, 5)

# %%
dataFrameMisc11=pd.read_csv('misc11.csv')
dataFrameisolates=pd.read_csv('isolates.csv')
dataFramePred=pd.read_csv('pred.csv')

# %%
dataFrameMisc11.head(5)
# Out:
#   Gene(Sequences_available_in_Github)                 Function  \
# 0                                menA  Uncharacterized protein
# 1                         group_42361  Uncharacterized protein
# 2                                menA  Uncharacterized protein
# 3                         group_17190     hypothetical protein
# 4                                wbuC     hypothetical protein
#
#    Average_Importance_50_replica  Average_Rank_in_50_replica  \
# 0                       0.018865                 1888.812500
# 1                       0.002059                 2085.000000
# 2                       0.002319                  691.333333
# 3                     100.000000                    1.000000
# 4                      28.467702                    3.340000
#
#    Frequency_of_appearance_in_50_replica Antibiotic
# 0                                     16        AMP
# 1                                      2        AMP
# 2                                      3        TBM
# ...

# %%
dataFrameisolates.head(5)
# Out:
#   ENA.Accession.Number     Isolate Lane.accession     Sequecning Status  \
# 0            ERS356929  11657_5#10      ERR434268  Previously sequenced
# 1            ERS356935  11657_5#11      ERR434269  Previously sequenced
# 2            ERS356938  11657_5#12      ERR434270  Previously sequenced
# 3            ERS356941  11657_5#13      ERR434271  Previously sequenced
# 4            ERS356967  11657_5#14      ERR434272  Previously sequenced
#
#      Year CTZ CTX AMP  AMX AMC TZP CXM CET GEN TBM TMP CIP
# 0  2010.0   S   S   S  NaN   S   S   S   I   S   S   S   S
# 1  2010.0   S   S   R  NaN   R   S   S   I   S   S   R   R
# 2  2010.0   S   S   S  NaN   S   S   S   S   S   S   S   S
# 3  2010.0   S   S   R  NaN   R   S   S   I   S   S   S   R
# 4  2010.0   S   S   R  NaN   S   S   S   S   S   S   R   S

# %%
dataFramePred.head(5)
# Out:
#      Isolates Prediction Observation Antibiotic
# 0  11657_5#10          S           S        CTZ
# 1  11657_5#11          S           S        CTZ
# 2  11657_5#12          S           S        CTZ
# 3  11657_5#13          S           S        CTZ
# 4  11657_5#14          S           S        CTZ
